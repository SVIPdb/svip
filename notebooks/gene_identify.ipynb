# %%
import mygene

# %%
mg = mygene.MyGeneInfo()

# %%
mg.query('symbol:BRAF', fields='symbol,ensembl,accession,uniprot', species='human')
# Out:
# {'max_score': 88.29799,
#  'took': 8,
#  'total': 1,
#  'hits': [{'_id': '673',
#    '_score': 88.29799,
#    'accession': {'genomic': ['AC006006.2',
#      'AC006344.2',
#      'AC006347.2',
#      'AC079339.5',
#      'CH236950.1',
#      'CH471070.1',
#      'EU600171.1',
#      'HB432546.1',
#      'HC464558.1',
#      'HM459603.1',
#      'HQ224878.1',
#      'KF481581.1',
#      'KT584890.1',
#      'KY769663.1',
#      'KY769664.1',
#      'KY769665.1',
#      'KY769666.1',
#      'KY769667.1',
#      'KY769668.1',
#      'NC_000007.14',
#      'NG_007873.3',
#      'X65187.1'],
#     'protein': ['AAA35609.2',
#      'AAA96495.1',
#      'AAD15551.1',
#      'AAD43193.1',
#      'AAI01758.1',
#      'AAI12080.1',
#      'AAS00359.1',
#      'ACD11489.1',
#      'ADN43065.1',
#      'ADQ00186.1',
#      'ADX94397.1',
#      'AIE38317.1',
#      'ARR27440.1',
#      'ARR27441.1',
#      'ARR27442.1',
#      'ARR27443.1',
#      'ARR27444.1',
#      'ARR27445.1',
# ...
